# %% [markdown]
# ## Webscraping - Marmiton

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
import time
import pandas as pd
import gc

# %%
# Configurer le WebDriver pour Firefox
options = Options()
options.add_argument('--headless')
options.add_argument('--disable-gpu')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Firefox(options=options)

# %%
# URL de la page à scraper
url = "https://www.marmiton.org/recettes/recette_couscous-royal_535913.aspx"
driver.get(url)

# %%
# XPath du bouton à cliquer
xpath_button = '//*[@id="didomi-notice-agree-button"]'  # Remplacez par l'XPath correct

# Attendre que le bouton soit cliquable
button = WebDriverWait(driver, 10).until(
    EC.element_to_be_clickable((By.XPATH, xpath_button))
)

# Cliquer sur le bouton
button.click()

# Continuer avec le reste de votre script
print("Bouton cliqué avec succès.")

# %%
titre_recette = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[2]/div[1]/h1').text.strip()
print(titre_recette)

# %%
temps_total = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[8]/div[2]/div[1]/div').text.strip()
print(temps_total)

# %%
temps_preparation = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[9]/div[2]/div[2]/div[1]/div').text.strip()
print(temps_preparation)

# %%
temps_cuisson = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[9]/div[2]/div[2]/div[3]/div').text.strip()
print(temps_cuisson)

# %%
difficulty = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[4]/div[2]/span').text.strip()
print(difficulty)

# %%
nb_personne = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[6]/div[2]/div[1]/div[1]/div/div[2]/input').get_attribute('value')
print(nb_personne)

# %%
# Extraire ingredients
liste_ingredients = []
elements  = driver.find_elements(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[5]/div[2]/div[2]')
for element in elements:
    for card in driver.find_elements(By.XPATH, '//*[contains(@class, "card-ingredient-title")]'):
        liste_ingredients.append(card.text.strip().replace('\n', ' '))

# %%
liste_ingredients

# %%
liste_etapes = []
etapes = driver.find_elements(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[9]/div')
for etape in etapes:
    for s in driver.find_elements(By.XPATH, '//*[contains(@class, "recipe-step-list__container")]'):
        liste_etapes.append(s.text.strip().replace('\n', ' '))

# %%
liste_etapes

# %%
# Creation des listes vierges
liste_titre = []
liste_temps_total = []
liste_temps_preparation = []
liste_temps_cuisson = []
liste_difficulty = []
liste_nb = []
liste_ingredients = []
liste_etapes = []

# Recuperations des informations
titre_recette = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[2]/div[1]/h1').text.strip()
temps_total = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[8]/div[2]/div[1]/div').text.strip()
temps_preparation = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[9]/div[2]/div[2]/div[1]/div').text.strip()
temps_cuisson = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[9]/div[2]/div[2]/div[3]/div').text.strip()
difficulty = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[4]/div[2]/span').text.strip()
nb_personne = driver.find_element(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[6]/div[2]/div[1]/div[1]/div/div[2]/input').get_attribute('value')

liste_titre.append(titre_recette)
liste_temps_total.append(temps_total)
liste_temps_preparation.append(temps_preparation)
liste_temps_cuisson.append(temps_cuisson)
liste_difficulty.append(difficulty)
liste_nb.append(nb_personne)

liste_ingredients_temp = []
elements  = driver.find_elements(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[5]/div[2]/div[2]')
for element in elements:
    for card in driver.find_elements(By.XPATH, '//*[contains(@class, "card-ingredient-title")]'):
        liste_ingredients_temp.append(card.text.strip().replace('\n', ' '))
liste_ingredients.append(liste_ingredients_temp)

liste_etapes_temp = []
etapes = driver.find_elements(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[9]/div')
for etape in etapes:
    for s in driver.find_elements(By.XPATH, '//*[contains(@class, "recipe-step-list__container")]'):
        liste_etapes_temp.append(s.text.strip().replace('\n', ' '))
liste_etapes.append(liste_etapes_temp)

# %%
print(f"Longueur de liste_titre: {len(liste_titre)}")
print(f"Longueur de liste_temps_total: {len(liste_temps_total)}")
print(f"Longueur de liste_temps_preparation: {len(liste_temps_preparation)}")
print(f"Longueur de liste_temps_cuisson: {len(liste_temps_cuisson)}")
print(f"Longueur de liste_difficulty: {len(liste_difficulty)}")
print(f"Longueur de liste_nb: {len(liste_nb)}")
print(f"Longueur de liste_ingredients_temp: {len(liste_ingredients)}")
print(f"Longueur de liste_etapes: {len(liste_etapes)}")

# %%
dataset_recette = pd.DataFrame({
    'Titre': liste_titre,
    'Temps_total': liste_temps_total,
    'Temps_preparation': liste_temps_preparation,
    'Temps_cuisson': liste_temps_cuisson,
    'Difficulté': liste_difficulty,
    'Nombre_de_personnes': liste_nb,
    'Ingredients': liste_ingredients,
    'Etapes': liste_etapes
})

# %% [markdown]
# ### Recuperer une liste de liens pointant vers les recettes

# %%
URL_ROOT = "https://www.marmiton.org/recettes/index/categorie/plat-principal"

with open("liens-recettes-v1.csv", "a", encoding='utf-8') as f:
    for i in range(1, 570):
        time.sleep(1)
        URL_PAGE_PATH = f"{URL_ROOT}/{i}"
        driver.get(URL_PAGE_PATH)
        # Rechercher les éléments avec la classe 'mrtn-card__title' uniquement à l'intérieur de 'recette'
        titre_elements = driver.find_elements(By.XPATH, './/*[contains(@class, "mrtn-card__title")]/a')
        for titre_element in titre_elements:
            f.write(f"{titre_element.text.strip()};{titre_element.get_attribute('href')}\n")

# %% [markdown]
# ### Charger le dataset

# %%
dataset = pd.read_csv("liens-recettes-v1.csv", sep=";", encoding='utf-8')
dataset
# Out:
#                                                  Recette  \
# 0         Cuisse de dinde façon couscous de chez Karpeth
# 1                    Blanquette de veau facile au Cookeo
# 2                      Terrine de foie gras au Sauternes
# 3                                         Couscous Royal
# 4                 Quiche jambon, fromage, tomate, olives
# ...                                                  ...
# 17065  Wok de poulet, courgettes et vermicelles de ri...
# 17066                               Wok poivron et dinde
# 17067                       Wok tomaté aux dés de poulet
# 17068                              Wrap pizza au chorizo
# 17069                           Yassa de poulet moutardé
#
#                                            Liens_recette
# 0      https://www.marmiton.org/recettes/recette_cuis...
# 1      https://www.marmiton.org/recettes/recette_blan...
# 2      https://www.marmiton.org/recettes/recette_terr...
# 3      https://www.marmiton.org/recettes/recette_cous...
# 4      https://www.marmiton.org/recettes/recette_quic...
# ...                                                  ...
# 17065  https://www.marmiton.org/recettes/recette_wok-...
# 17066  https://www.marmiton.org/recettes/recette_wok-...
# 17067  https://www.marmiton.org/recettes/recette_wok-...
# 17068  https://www.marmiton.org/recettes/recette_wrap...
# 17069  https://www.marmiton.org/recettes/recette_yass...
#
# [17070 rows x 2 columns]

# %%
dataset.info()

# %% [markdown]
# ### Recuperer les recettes et les mettres dans le dataset

# %%
liste_titre = []
liste_temps_total = []
liste_temps_preparation = []
liste_temps_cuisson = []
liste_difficulty = []
liste_nb = []
liste_ingredients = []
liste_etapes = []
liste_cout = []

df = pd.DataFrame(columns=['Titre', 'Temps Total', 'Temps Préparation', 'Temps Cuisson', 'Difficulté', 'Nombre de personnes', 'Coût', 'Ingrédients', 'Étapes', 'Liens_recette'])
counter = 0

for lien in dataset['Liens_recette']:
    print(lien)
    driver.get(lien)
    
    '''WebDriverWait(driver, 10).until(
        lambda d: d.execute_script('return document.readyState') == 'complete'
    )
'''
    # Recuperations des informations
    titre_recette = driver.find_element(By.CSS_SELECTOR, '.main-title > h1:nth-child(1)').text.strip()
    temps_total = driver.find_element(By.CSS_SELECTOR, '.time__total > div:nth-child(2)').text.strip()
    temps_preparation = driver.find_element(By.CSS_SELECTOR, '.time__details > div:nth-child(1) > div:nth-child(2)').text.strip()
    temps_cuisson = driver.find_element(By.CSS_SELECTOR, '.time__details > div:nth-child(3) > div:nth-child(2)').text.strip()
    difficulty = driver.find_element(By.CSS_SELECTOR, 'div.recipe-primary__item:nth-child(3) > span:nth-child(2)').text.strip()
    nb_personne = driver.find_element(By.CSS_SELECTOR, '.recipe-ingredients__qt-counter__value').get_attribute('value')
    cout = driver.find_element(By.CSS_SELECTOR, 'div.recipe-primary__item:nth-child(5) > span:nth-child(2)').text.strip()

    liste_ingredients = []
    elements  = driver.find_elements(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[5]/div[2]/div[2]')
    for element in elements:
        for card in driver.find_elements(By.XPATH, '//*[contains(@class, "card-ingredient-title")]'):
            liste_ingredients.append(card.text.strip().replace('\n', ' '))

    liste_etapes = []
    etapes = driver.find_elements(By.XPATH, '/html/body/div[7]/div[2]/div[1]/div[9]/div')
    for etape in etapes:
        for s in driver.find_elements(By.XPATH, '//*[contains(@class, "recipe-step-list__container")]'):
            liste_etapes.append(s.text.strip().replace('\n', ' '))

    # Créer un dictionnaire pour la nouvelle ligne
    nouvelle_ligne = {
        'Titre': titre_recette,
        'Temps Total': temps_total,
        'Temps Préparation': temps_preparation,
        'Temps Cuisson': temps_cuisson,
        'Difficulté': difficulty,
        'Nombre de personnes': nb_personne,
        'Coût': cout,
        'Ingrédients': liste_ingredients,
        'Étapes': liste_etapes,
        'Liens_recette': lien
    }

    # Ajouter la nouvelle ligne au DataFrame
    df = pd.concat([df, pd.DataFrame([nouvelle_ligne])], ignore_index=True)

    # Incrémenter le compteur
    counter += 1
    print(counter)

    # Redémarrer le navigateur périodiquement
    if counter % 75 == 0:
        driver.quit()
        driver = webdriver.Firefox(options=options)
        url = "https://www.marmiton.org/recettes/recette_couscous-royal_535913.aspx"
        driver.get(url)
        # XPath du bouton à cliquer
        xpath_button = '//*[@id="didomi-notice-agree-button"]'
        # Attendre que le bouton soit cliquable
        button = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, xpath_button))
        )
        # Cliquer sur le bouton
        button.click()
        gc.collect()
        
    del titre_recette
    del temps_total
    del temps_preparation
    del temps_cuisson
    del nb_personne
    del cout
    del liste_ingredients
    del liste_etapes
    gc.collect()

# %%
df

# %% [markdown]
# ### Tester avec request et bs4

# %%
import requests
from bs4 import BeautifulSoup
from lxml import etree

# %%
liste_titre = []
liste_temps_total = []
liste_temps_preparation = []
liste_temps_cuisson = []
liste_difficulty = []
liste_nb = []
liste_ingredients = []
liste_etapes = []
liste_cout = []

df = pd.DataFrame(columns=['Titre', 'Temps Total', 'Temps Préparation', 'Temps Cuisson', 'Difficulté', 'Coût', 'Ingrédients', 'Étapes', 'Liens_recette'])

for lien in dataset['Liens_recette']:
    print(lien)
    
    # Recuperer le contenu de la page
    response = requests.get(lien)
    response.raise_for_status()  # Vérifier si la requête a réussi

    # Parser le contenu HTML avec BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Recuperations des informations
    # Récupérer les informations avec des CSS selectors
    titre_recette = soup.select_one('.main-title > h1:nth-child(1)').text.strip()
    temps_total = soup.select_one('.time__total > div:nth-child(2)').text.strip()
    temps_preparation = soup.select_one('.time__details > div:nth-child(1) > div:nth-child(2)').text.strip()
    temps_cuisson = soup.select_one('.time__details > div:nth-child(3) > div:nth-child(2)').text.strip()
    difficulty = soup.select_one('div.recipe-primary__item:nth-child(3) > span:nth-child(2)').text.strip()
    cout = soup.select_one('div.recipe-primary__item:nth-child(5) > span:nth-child(2)').text.strip()

    # Récupérer les ingrédients
    liste_ingredients_temp = []
    for card in soup.select('.card-ingredient-title'):
        liste_ingredients_temp.append(card.text.strip().replace('\n', ' '))

    # Récupérer les étapes
    liste_etapes_temp = []
    for step in soup.select('.recipe-step-list__container'):
        liste_etapes_temp.append(step.text.strip().replace('\n', ' '))\
        
    # Récupération des ingrédients avec BeautifulSoup
    liste_ingredients = []
    elements = soup.select('div.recipe-ingredients__list div.card-ingredient-title')  # Sélecteur CSS
    for card in elements:
        liste_ingredients.append(card.text.strip().replace('\n', ' '))

    # Récupération des étapes avec BeautifulSoup
    liste_etapes = []
    etapes = soup.select('div.recipe-step-list__container')  # Sélecteur CSS
    for step in etapes:
        liste_etapes.append(step.text.strip().replace('\n', ' '))


    # Créer un dictionnaire pour la nouvelle ligne
    nouvelle_ligne = {
        'Titre': titre_recette,
        'Temps Total': temps_total,
        'Temps Préparation': temps_preparation,
        'Temps Cuisson': temps_cuisson,
        'Difficulté': difficulty,
        'Coût': cout,
        'Ingrédients': liste_ingredients,
        'Étapes': liste_etapes,
        'Liens_recette': lien
    }

    # Ajouter la nouvelle ligne au DataFrame
    df = pd.concat([df, pd.DataFrame([nouvelle_ligne])], ignore_index=True)

# %% [markdown]
# ### Test avec Pyppeeter

# %%
# !pip install pyppeteer

# %%
import nest_asyncio
import pandas as pd
from pyppeteer import launch
import csv

# Appliquer le patch nest_asyncio
nest_asyncio.apply()

df = pd.DataFrame(columns=['Titre', 'Temps Total', 'Temps Préparation', 'Temps Cuisson', 'Difficulté', 'Coût', 'Ingrédients', 'Étapes', 'Liens_recette', 'Ustensiles'])

browser = await launch(executablePath='C:\\chrome\\chrome.exe', headless=False, args=['--no-sandbox', '--disable-dev-shm-usage'])
page = await browser.newPage()

with open("recettes-marmiton.csv", mode='a', newline='', encoding='utf-8') as fichier_csv:
    for idx, lien in enumerate(dataset['Liens_recette']):
        print(f"{idx}:{lien}")

        await page.goto(lien)

        # Récupérer les informations avec des CSS selectors
        titre_recette = await page.querySelectorEval('.main-title > h1:nth-child(1)', 'node => node.textContent.trim()')
        temps_total = await page.querySelectorEval('.time__total > div:nth-child(2)', 'node => node.textContent.trim()')
        temps_preparation = await page.querySelectorEval('.time__details > div:nth-child(1) > div:nth-child(2)', 'node => node.textContent.trim()')
        temps_cuisson = await page.querySelectorEval('.time__details > div:nth-child(3) > div:nth-child(2)', 'node => node.textContent.trim()')
        difficulty = await page.querySelectorEval('div.recipe-primary__item:nth-child(3) > span:nth-child(2)', 'node => node.textContent.trim()')
        cout = await page.querySelectorEval('div.recipe-primary__item:nth-child(5) > span:nth-child(2)', 'node => node.textContent.trim()')
        nb_personne = await page.querySelectorEval('.recipe-ingredients__qt-counter__value', 'node => node.getAttribute("value")')

        # Récupérer les ingrédients
        liste_ingredients_temp = []
        ingredients = await page.querySelectorAll('.card-ingredient-title')
        for ingredient in ingredients:
            ingredient_text = await (await ingredient.getProperty('textContent')).jsonValue()
            # Nettoyer les espaces superflus
            ingredient_text = ' '.join(ingredient_text.replace('\n', ' ').strip().split())
            liste_ingredients_temp.append(ingredient_text)

        # Récupérer les étapes
        liste_etapes_temp = []
        steps = await page.querySelectorAll('.recipe-step-list__container')
        for step in steps:
            step_text = await (await step.getProperty('textContent')).jsonValue()
            # Nettoyer les espaces superflus
            step_text = ' '.join(step_text.replace('\n', ' ').strip().split())
            liste_etapes_temp.append(step_text)

        # Récupérer les ustensiles
        liste_ustensiles_temp = []
        steps = await page.querySelectorAll('.mrtn-recette_utensils-items .card-utensil')
        for step in steps:
            step_text = await (await step.getProperty('textContent')).jsonValue()
            # Nettoyer les espaces superflus
            step_text = ' '.join(step_text.replace('\n', ' ').strip().split())
            liste_ustensiles_temp.append(step_text)

        print(liste_ingredients_temp)
        print(liste_etapes_temp)
        print(liste_ustensiles_temp)

        # Créer un dictionnaire pour la nouvelle ligne
        nouvelle_ligne = {
            'Titre': titre_recette,
            'Temps Total': temps_total,
            'Temps Préparation': temps_preparation,
            'Temps Cuisson': temps_cuisson,
            'Difficulté': difficulty,
            'Coût': cout,
            'Ingrédients': liste_ingredients_temp,
            'Étapes': liste_etapes_temp,
            'Liens_recette': lien,
            'Ustensiles': liste_ustensiles_temp
        }

        writer = csv.DictWriter(fichier_csv, fieldnames=nouvelle_ligne.keys(), delimiter=";")
        writer.writerow(nouvelle_ligne)
# Out:
# 0:https://www.marmiton.org/recettes/recette_cuisse-de-dinde-facon-couscous-de-chez-karpeth_41363.aspx
# ['2 courgettes , diamètre 4 ou 5 cm', '3 carottes', '1 boîte moyenne de pois chiches', 'beurre', "1 cuisse de dinde d'un peu plus d'1 kg (et non un cochon d'Inde)", '6 échalotes (ou 2 gros oignons)', '1 bulbe de fenouil', '12 dattes', '200 g de semoule moyenne', "huile d'olive", 'sel', '3 cuillères à soupe de persil ciselé lyophilisé ou frais', 'tabasco', '2 cuillères à soupe de piment doux ou paprika en poudre', '2 cuillères à soupe de quatre-épices (cannelle, muscade, girofle, poivre)', '2 cubes de bouillon de volaille', "1 cuillère à café d' ail en semoule ou 2 gousses d’ail hachées", '2 cuillères à café de laurier en poudre (ou 2 feuilles)']
# ['Étape 1 1 casserole pour préparer la semoule (ou 1 bol si on la prépare au micro-ondes). J’vous raconte ça car en ce moment, je n’ai qu’un seul « feu » d’utilisable, alors cela fait partie du cahier des charges pour le choix des repas : pas deux trucs qui cuisent en même temps. Pis ça fait moins de vaisselle', 'Étape 2 D’abord on s’occupe de la viande.', 'Étape 3 Enlever le surplus de gras et les éventuelles esquilles de la cuisse de dinde.', 'Étape 4 Mettre la sauteuse sur feu vif. Dès qu’elle est bien chaude, y déposer la cuisse avec le côté peau au contact de la poêle. Passer à feu moyen.', 'Étape 5 Ajouter les échalotes épluchées et coupées en 4 ou 6. Laisser dorer. Retourner et laisser bien dorer l’autre coté. En gros, tout ça prend 8 min.', 'Étape 6 Arroser avec 1 cuillère à soupe de paprika ou piment doux et 1 cuillère à soupe de 4 épices le côté chair, retourner la pièce pour laisser cuire ce côté chair une petite minute, à feu pas trop vif.', 'Étape 7 Ajouter 3/4 l d’eau tiède, gratter un peu le fond de la sauteuse pour décoller les sucs. Ajouter les 2 cubes de bouillon, 3 traits de Tabasco, l’ail, 1 cuillère à soupe de persil, le laurier et ½ cuillère à café de sel.', 'Étape 8 Laisser mijoter la viande en couvrant la sauteuse pendant 45 min en la retournant 1 ou 2 fois.', 'Étape 9 Pendant ce temps, on prépare les légumes :', 'Étape 10 Eplucher des carottes, les couper en tronçons de 4 cm.', 'Étape 11 Eplucher les courgettes en enlevant une bande de peau sur deux et les couper en grosses rondelles d’environ 3 cm.', 'Étape 12 Là, rien de plus car mon cochon d’inde ne mange pas les courgettes.', 'Étape 13 Nettoyer le bulbe de fenouil et le couper en 4.', 'Étape 14 Egoutter les pois chiches.', 'Étape 15 Au bout des 45 min de cuisson de la viande, ouvrir la sauteuse.', 'Étape 16 Enlever l’écume sur le bouillon s’il y en a. Retourner la cuisse et ajouter tout les légumes sauf les pois chiches.', 'Étape 17 Laisser le bouillon rebouillir et ajuster le feu pour que ça reste frémissant. Refermer la sauteuse et laisser 25 min.', 'Étape 18 Nous voilà au bout de 1h10 min de cuisson totale.', 'Étape 19 Ouvrir la sauteuse, retourner la viande et ajouter les pois chiches et les dattes.', 'Étape 20 Saupoudrer du reste des épices : 1 trait de Tabasco (facultatif), 1 cuillère à soupe de 4 épices, 1 cuillère à soupe de piment doux ou paprika et 2 cuillères à soupe de persil.', 'Étape 21 Laisser mijoter encore 15 min. Goûter le bouillon et ajuster pour le sel et le tabasco.', 'Étape 22 Préparer la semoule selon le mode d’emploi du paquet ou comme suit :', 'Étape 23 Prendre 200 g de semoule moyenne. Ça fait un mug de semoule (en tout cas mes mugs sont comme ça !).', 'Étape 24 Faire chauffer le même volume d’eau (ça marche aussi avec l’eau bien chaude du robinet). Y ajouter 1 cuillère à café de sel et 1 cuillère à soupe d’huile d’olive.', 'Étape 25 Verser la semoule en pluie dans l’eau et laisser gonfler deux minutes. On peut aussi tout mettre au micro-onde pendant 1 minute.', 'Étape 26 Quand la semoule a gonflé, ajouter deux belles noisettes de beurre, non, deux noix c’est plus gros. La semoule c’est bon parce que ça a le goût du beurre, donc y’en faut ! Mais bon, vu que là on a un plat tip-top diététique-super-bon-pas-gras-équilibré on va pas tout ruiner maintenant. On laisse fondre le beurre et on égrène à la fourchette.', 'Étape 27 Si on a la joie d’avoir un deuxième brûleur, ou bien en écartant momentanément notre cuisse de dinde du brûleur, passer la semoule à la casserole quelques minutes tout en séparant les grains à la fourchette.', 'Étape 28 A table !!', 'Étape 29 Un peu de semoule au beurre, les légumes fondants, la viande mœlleuse et le bouillon parfumé…']
# ['1 Couteau Top des meilleurs couteaux de cuisine + de détails', '1 Couvercle Les meilleures ventes Acheter', '1 sauteuse Top 3 des sauteuses + de détails', '1 casserole Top 3 des batteries de casseroles + de détails', '1 Micro-ondes Le top des micro-ondes + de détails', '1 bol Top des saladiers + de détails', '1 Set 3 poêles Notre sélection des meilleures poêles + de détails', '1 pinceau 6,72€ + de détails', '1 économe Top 5 des meilleurs économe + de détails', '1 Four top des meilleurs fours + de détails', '1 fourchette + de détails', '1 balance de cuisine Top des meilleures balances + de détails', '1 plat + de détails', '1 cuillère à soupe + de détails']
# 1:https://www.marmiton.org/recettes/recette_blanquette-de-veau-facile-au-cookeo_383136.aspx
# ['2 carottes', '1 oignon jaune', '1 petit pot de crème fraîche', '2 cuillères à soupe de farine', '10 g de beurre doux', '1 kg de blanquette de veau', '1 petite boîte de champignon (coupés)', '1 cube de bouillon de légumes', '1 cube de bouillon de poule', '25 cl de vin blanc', "2 jaunes d'oeuf", '1 cuillère à café de jus de citron', 'sel et poivre']
# ["Étape 1 Coupez la viande en morceaux de taille moyenne puis placez-la dans la cuve du Cookeo. Faites-la revenir avec le beurre doux jusqu'à ce que les morceaux soient un peu dorés sur le mode « dorer » / 3 min (préchauffage inclus), en remuant avec une cuillère en bois / stoppez avant l’étape 2.", 'Étape 2 Saupoudrez avec la farine. Remuez bien.', "Étape 3 Versez 40 cl d’eau, les cubes de bouillon, le vin. Ajoutez de l'eau si nécessaire pour couvrir.", 'Étape 4 Épluchez puis coupez les carottes en rondelles. Émincez l’oignon. Versez le tout dans la cuve. Ajoutez les champignons égouttés.', 'Étape 5 Laissez mijoter doucement dans le Cookeo sur le mode « cuisson sous pression » / 45 min. Si la préparation est trop liquide, ajoutez un peu de farine.', 'Étape 6 Dans un bol, mélangez bien la crème fraîche, les jaunes d’œufs et le jus de citron. Ajoutez ce mélange en fin de cuisson, puis remuez bien.']
# ['1 Cookeo Les meilleures ventes Acheter', '1 Cuillère en bois Les meilleures ventes Acheter', '1 bol Top des saladiers + de détails', '1 Mijoteuse électrique Les meilleures ventes Acheter', '1 balance de cuisine Top des meilleures balances + de détails']
# 2:https://www.marmiton.org/recettes/recette_terrine-de-foie-gras-au-sauternes_33977.aspx
# ['3 pincées de quatre-épices', '15 g de sel', '1 pincée de poivre', '2 foie (environ 1,200 kg)', '2 pincées de paprika', '½ verre de Sauternes']
# ['Étape 1 A préparer 4 ou 5 jours avant.', "Étape 2 Faire tremper les foies dans de l'eau fraîche pendant 1 h.", 'Étape 3 Enlever la veine centrale, les nerfs et les marques de fiel.', 'Étape 4 Mélanger le sel, le poivre, les épices et le paprika.', 'Étape 5 Répartir le mélange sur les faces.', 'Étape 6 Installer les foies côté rond, côté terrine.', 'Étape 7 Les tasser (sans les écraser, ne pas hésiter à "boucher" les trous).', 'Étape 8 Arroser de Sauternes.', 'Étape 9 Souder la terrine avec de la pâte farine/eau (veiller à laisser libre la petite cheminée).', 'Étape 10 Cuire au bain-marie chaud, four Th 3 (120°C ) pendant une heure.', 'Étape 11 Dans un four électrique, laisser le foie se refroidir dans le four.', 'Étape 12 Dans un four à gaz, envelopper la terrine dans une couverture et le laisser refroidir doucement (5 h).', 'Étape 13 Garder au frigo, terrine soudée pendant 4 ou 5 jours.', "Étape 14 Démouler au moment de servir en trempant le fond de la terrine quelques secondes dans de l'eau chaude et à l'aide d'un couteau trempé également dans l'eau chaude."]
# ['1 Cuillère en bois Les meilleures ventes Acheter', '1 saladier Les meilleures ventes Acheter', '1 Four Top des meilleurs fours + de détails', '1 couteau Top 3 des couteaux + de détails', '1 balance de cuisine Top des meilleures balances + de détails']
# 3:https://www.marmiton.org/recettes/recette_couscous-royal_535913.aspx
# ['1 barquette d’émincé 100% végétal ACCRO', '4 merguez végétales ACCRO', '100 g de couscous', "100 g d' eau", "5 cl d' huile d'olive", '100 g de carotte', '100 g de navet', '80 g de courgette', '100 g de potiron', '100 g de chou vert', '40 g de pois chiches', "80 g d' aubergine", '80 g de tomates grappes', "50 g d' oignon", '50 g de tomate', '¼ botte de persil plat', '¼ botte de coriandre', '25 g de concentré de tomates', '1 g de curcuma', '3 g de gingembre en poudre', '10 g de gingembre frais', "60 cl d' eau", 'parures de légumes (carottes, navet, courgettes)']
# ['Étape 1 Préparation de la semoule : placez la semoule dans un plat creux. Salez. Versez l’huile d’olive et mélangez. Portez l’eau à ébullition, puis versez l’eau bouillante sur la semoule. Couvrez et laissez reposer 5 minutes. Égrenez les graines avec une fourchette. Réservez.', 'Étape 2 Préparation des légumes : la veille, faites tremper les pois chiches dans un grand volume d’eau, puis les cuire dans l’eau à feu doux pendant 2 heures. Épluchez les navets et les carottes. Coupez-les en gros bâtonnets de 5 cm. Taillez les aubergines et les courgettes en bâtonnets. Lavez et effeuillez le chou, ensuite coupez-le en quartier. Épluchez et taillez le potiron en morceaux. Réservez toutes les parures de légumes.', 'Étape 3 Préparation du bouillon de légumes : épluchez, lavez puis taillez en mirepoix les tomates et les oignons. Dans une casserole, faites chauffer un filet d’huile d’olive. Ajoutez les épices, les oignons et les tomates fraîches. Faites-les suer l’ensemble sans coloration. Mouillez avec l’eau. Ajoutez toutes les parures de légumes, le persil et la coriandre. Portez à ébullition. Laissez cuire à feu très doux durant une heure. Couvrez et laissez reposer 30 minutes hors du feu. Passez le bouillon au chinois fin.', 'Étape 4 Cuisson des légumes : faites-cuire les légumes dans le bouillon de légumes. Une fois les légumes cuits, passez le bouillon au chinois et réservez.', 'Étape 5 Cuisson des merguez et émincés ACCRO : faites cuire les merguez végétales et les émincés ACCRO pendant 3 minutes 30.', 'Étape 6 Finition et présentation du couscous : dans un tajine ou un plat très large, dressez en dôme la semoule. Formez un cratère sur le dôme. Disposez les émincés 100% végétaux ACCRO puis autour de la semoule les légumes en alternant les couleurs et terminez avec les merguez végétales ACCRO. Nappez de bouillon. Servir très chaud.']
# ['1 plat + de détails', '1 casseroles + de détails', '1 couteau + de détails']
# 4:https://www.marmiton.org/recettes/recette_quiche-jambon-fromage-tomate-olives_535806.aspx
# ["4 tranches de jambon cuit à l'Étouffée LE BON PARIS® HERTA®", '140 g de Râpé typé RICHESMONTS®', '1 Pâte Feuilletée HERTA® Trésor de Grand Mère', 'basilic (quelques feuilles)', '3 oeufs', '20 cl de crème fraîche', '20 cl de lait', '10 cl de coulis de tomate', '10 olives noires', 'huile pimentée pour pizza', "1 pincée d' origan", '1 pincée de sel et poivre']
# ['Étape 1 Préchauffez le four à 200°C en chaleur tournante. Déroulez la pâte avec son papier cuisson dans un moule, piquez le fond avec une fourchette.', 'Étape 2 Répartissez dessus le coulis de tomate puis le jambon à l’étouffée Herta® coupé en morceaux et le râpé typé RichesMonts®.', 'Étape 3 Mélangez les œufs, le lait et la crème. Assaisonnez en sel, poivre et origan. Versez dans le moule, ajoutez les olives et enfournez pour 25 à 30 minutes.', 'Étape 4 Laissez tiédir, puis servez avec le basilic et 1 filet d’huile pimentée.']
# ['1 moule à tarte + de détails', '1 fourchette + de détails', '1 saladier + de détails']
# 5:https://www.marmiton.org/recettes/recette_roules-de-jambon-blanc-au-reblochon-panure-pistache_535554.aspx
# ['1 Reblochon de Savoie AOP', '6 tranches de jambon blanc', '2 oeufs', '100 g de chapelure', '100 g de pistaches']
# ["Étape 1 Couper une tranche de Reblochon AOP dans le sens de la longueur puis la placer au milieu d'une tranche de jambon avant de l'enrouler.", "Étape 2 Incorporer les brisures de pistaches dans la chapelure, bien mélanger l'ensemble.", "Étape 3 Battre 2 œufs, saler, poivrer. Tremper chaque roulé de jambon dans l'oeuf puis dans la chapelure de pistaches et faire frire 5 min de chaque côté à feu doux."]
# ['1 poêle + de détails', '1 planche + de détails', '1 couteau + de détails', '1 bol + de détails']
# 6:https://www.marmiton.org/recettes/recette_la-vraie-tartiflette_17634.aspx
# ['200 g de lardons fumés', "200 g d' oignon émincés", "1 reblochon bien fait (lorsqu'on appuie sur le côté du reblochon, le doigt doit s'enfoncer un peu)", "2 cuillères à soupe d' huile", 'sel', 'poivre', '1 kg de pomme de terre', "1 gousse d' ail"]
# ['Étape 1 Eplucher les pommes de terre, les couper en dés, bien les rincer et les essuyer dans un torchon propre.', "Étape 2 Faire chauffer l'huile dans une poêle, y faire fondre les oignons.", 'Étape 3 Lorsque les oignons sont fondus, ajouter les pommes de terre et les faire dorer de tous les côtés.', "Étape 4 Lorsqu'elles sont dorées, ajouter les lardons et finir de cuire. Éponger le surplus de gras avec une feuille de papier essuie-tout.", "Étape 5 D'autre part, gratter la croûte du reblochon et le couper en deux (ou en quatre).", "Étape 6 Préchauffer le four à 200°C (thermostat 6-7) et préparer un plat à gratin en frottant le fond et les bords avec la gousse d'ail épluchée.", 'Étape 7 Dans le plat à gratin, étaler une couche de pommes de terre aux lardons, disposer dessus la moitié du reblochon, puis de nouveau des pommes de terre. Terminer avec le reste du reblochon (croûte vers les pommes de terre).', 'Étape 8 Enfourner pour environ 20 minutes de cuisson.']
# ['1 couteau Top 3 des couteaux + de détails', '1 économe Top 5 des meilleurs économe + de détails', '1 Set 3 poêles Notre sélection des meilleures poêles + de détails', '1 Four Top des meilleurs fours + de détails', '1 Plat à gratin Notre top des plats à four + de détails', '1 planche à découper Top des meilleures planches à découper + de détails', '1 plat + de détails']
# 7:https://www.marmiton.org/recettes/recette_lasagnes-a-la-bolognaise_18215.aspx
# ['1 paquet de lasagnes', '3 oignons jaunes', '125 g de beurre', '100 g de farine', 'poivre', 'sel', '70 g de fromage râpé', '3 pincées de muscade râpée', 'thym', '2 feuilles de laurier', '20 cl de vin rouge', '800 g de purée de tomate', '1 carotte', 'basilic', "15 cl d' eau", '125 g de Parmesan', '600 g de boeuf haché', '1 branche de céleri', "2 gousses d' ail", '1 l de lait']
# ["Étape 1 Faire revenir gousses hachées d'ail et les oignons émincés dans un peu d'huile d'olive.", 'Étape 2 Ajouter la carotte et la branche de céleri hachée puis la viande et faire revenir le tout.', "Étape 3 Au bout de quelques minutes, ajouter le vin rouge. Laisser cuire jusqu'à évaporation.", "Étape 4 Ajouter la purée de tomates, l'eau et les herbes. Saler, poivrer, puis laisser mijoter à feu doux 45 minutes.", 'Étape 5 Préparer la béchamel : faire fondre 100 g de beurre.', "Étape 6 Hors du feu, ajouter la farine d'un coup.", "Étape 7 Remettre sur le feu et remuer avec un fouet jusqu'à l'obtention d'un mélange bien lisse.", 'Étape 8 Ajouter le lait peu à peu.', "Étape 9 Remuer sans cesse, jusqu'à ce que le mélange s'épaississe.", 'Étape 10 Ensuite, parfumer avec la muscade, saler, poivrer. Laisser cuire environ 5 minutes, à feu très doux, en remuant. Réserver.', "Étape 11 Préchauffer le four à 200°C (thermostat 6-7). Huiler le plat à lasagnes. Poser une fine couche de béchamel puis des feuilles de lasagnes, de la bolognaise, de la béchamel et du parmesan. Répéter l'opération 3 fois de suite.", 'Étape 12 Sur la dernière couche de lasagnes, ne mettre que de la béchamel et recouvrir de fromage râpé. Parsemer quelques noisettes de beurre.', 'Étape 13 Enfourner pour environ 25 minutes de cuisson.', 'Étape 14 Déguster']
# ['1 pour vous guider en cuisine au quotidien Les meilleures ventes Acheter', '1 bol Top des saladiers + de détails', '1 Plat à gratin Notre top des plats à four + de détails', '1 couteau Top 3 des couteaux + de détails', '1 casserole Top 3 des batteries de casseroles + de détails', '1 Fouet cuisine Top 5 des meilleurs fouets Acheter', '1 saladier Les meilleures ventes Acheter', '1 Cuillère en bois Les meilleures ventes Acheter', '1 Four top des meilleurs fours + de détails', '1 Râpe Top des meilleures râpes + de détails', '1 sauteuse Top 3 des sauteuses + de détails', '1 Mixeur Les meilleures ventes Acheter', '1 balance de cuisine Top des meilleures balances + de détails', '1 plat + de détails']
# 8:https://www.marmiton.org/recettes/recette_blanquette-de-veau-facile_19219.aspx
# ['2 carottes', '1 oignon jaune', '1 petit pot de crème fraîche', 'farine', 'sel', 'poivre', '1 kg de blanquette de veau', '1 cube de bouillon de légumes', '1 bouillon de poule', '1 petite boîte de champignon (coupés)', 'citron', "1 jaune d'oeuf", '25 cl de vin blanc']
# ["Étape 1 Faire revenir la viande dans un peu de beurre doux jusqu'à ce que les morceaux soient un peu dorés.", 'Étape 2 Saupoudrer de 2 cuillères de farine. Bien remuer.', "Étape 3 Ajouter 2 ou 3 verres d'eau, les cubes de bouillon, le vin et remuer. Ajouter de l'eau si nécessaire pour couvrir.", 'Étape 4 Couper les carottes en rondelles et émincer les oignons puis les incorporer à la viande, ainsi que les champignons.', 'Étape 5 Laisser mijoter à feu très doux environ 1h30 à 2h00 en remuant.', "Étape 6 Si nécessaire, ajouter de l'eau de temps en temps.", 'Étape 7 Dans un bol, bien mélanger la crème fraîche, le jaune d’oeuf et le jus de citron. Ajouter ce mélange au dernier moment, bien remuer et servir tout de suite.']
# ['1 Cuillère en bois Les meilleures ventes Acheter', '1 couteau Top 3 des couteaux + de détails', '1 bol Top des saladiers + de détails', '1 pour vous guider en cuisine au quotidien Les meilleures ventes Acheter', '1 cocotte + de détails', '1 planche à découper Top des meilleures planches à découper + de détails', '1 louche Les meilleures ventes Acheter', '1 balance de cuisine Top des meilleures balances + de détails']
# 9:https://www.marmiton.org/recettes/recette_fondue-de-poireaux_20348.aspx
# ['600 g de poireau', '30 g de beurre', '1 cuillère à soupe de moutarde de Dijon', '2 cuillères à soupe de crème fraîche', 'sel', 'poivre du moulin', '2 cuillères à soupe de jus de citron']
# ['Étape 1 Coupez les poireaux en deux et recoupez-les en tronçons. Lavez soigneusement.', 'Étape 2 Faites fondre le beurre dans une casserole, ajoutez les poireaux, mélangez, couvrez et faites cuire à feu très doux pendant 25 min environ, en remuant de temps en temps.', 'Étape 3 A ce moment là ajoutez le jus de citron, la moutarde et la crème aux poireaux, salez légèrement, poivrez et mélangez bien.', 'Étape 4 Couvrez et laissez cuire encore 10 min à feu doux.']
# ['1 casserole Top 3 des batteries de casseroles + de détails', '1 saladier Les meilleures ventes Acheter', '1 Couvercle Les meilleures ventes Acheter', '1 couteau Top 3 des couteaux + de détails', '1 planche à découper Top des meilleures planches à découper + de détails', '1 balance de cuisine Top des meilleures balances + de détails']
# 10:https://www.marmiton.org/recettes/recette_poulet-au-four-version-light_218020.aspx
# ['2 oignons frais', '1 poignée de tomates cerise', 'feuille de laurier', '1 petite poignée de sel gros', 'poivre', "1 poulet fermier d'environ 1,8 kg", "3 gousses d' ail selon le goût", '1 cl de jus de citron', "1 bouillon de volaille dilué dans un verre d'eau"]
# ["Étape 1 Préchauffer le four à 200°C (thermostat 6). Placer à l'intérieur du poulet deux gousses d'ail et les feuilles de laurier.", 'Étape 2 Préparer la sauce en mélangeant le jus de citron et le verre de bouillon de volaille. Arroser copieusement le poulet et verser le reste du jus dans le plat.', 'Étape 3 Saupoudrer le gros sel sur le poulet.', 'Étape 4 Placer le poulet dans le plat, avec les oignons coupés en quatre et les tomates cerises.', "Étape 5 Placer le poulet au four durant environ 1 heure 40 à 200°C. (Au bout de 20 min de cuisson, retourner le poulet et laisser cuire 20 min, puis le replacer à l'endroit pour la suite de la cuisson)", "Étape 6 Attention : Arroser le poulet avec son jus le plus souvent possible durant la cuisson (ajouter de l'eau si nécessaire). Le poulet n'en sera que plus moelleux !", 'Étape 7 Récupérer le jus à la fin de la cuisson, avec les tomates et les oignons, dans un bol, et placer sur la table, avec une belle salade verte et une poêlée de pommes de terres nouvelles.']
# ['1 Four Top des meilleurs fours + de détails', '1 saladier Les meilleures ventes Acheter', '1 bol Top des saladiers + de détails', '1 Plat à gratin Notre top des plats à four + de détails', '1 dénoyauteur Les meilleures ventes Acheter', '1 plat + de détails']
# 11:https://www.marmiton.org/recettes/recette_couscous-poulet-et-merguez-facile_17751.aspx
# ['12 merguez', '1 cuillère à café de harissa', '3 tomates', '5 carottes', '2 courgettes', '400 g de pois chiches', '8 pilons de poulet (fermier de préférence)', "huile d'olive", '2 boîtes de concentré de tomates', "3 cuillères à soupe d' épices à couscous", '2 cubes de bouillon de boeuf', '10 navets']
# ['Étape 1 Lavez et épluchez les carottes, les navets et les tomates et les couper en cubes.', "Étape 2 Dans un autocuiseur, versez 3 cuillères à soupe d'huile d'olive. Mettez à chauffer et faites-y dorer les pilons de poulet. Quand ils sont dorés, versez l'équivalent d'1 litre d'eau et ajouter les cubes de bouillon de boeuf, le concentré de tomate, les carottes, navets et tomates, les épices à couscous et l'harissa.", 'Étape 3 Fermez votre autocuiseur et compter 25 mn de cuisson une fois que celui-ci est monté en pression.', 'Étape 4 En attendant, lavez et coupez les courgettes en cubes et égouttez les pois chiches.', 'Étape 5 Une fois les 25 mn écoulées, évacuez la vapeur de votre autocuiseur, ouvrez et rajouter les courgettes et les pois chiches.', 'Étape 6 Remettez au feu : comptez 10 mn de cuisson une fois votre autocuiseur sous pression.', 'Étape 7 Faites cuire vos merguez sur un grill ou à la poêle, mais pas avec les légumes.', "Étape 8 Servez accompagné d'une semoule fine."]
# ['1 couteau Top 3 des couteaux + de détails', '1 cocotte-minute + de détails', '1 pôele Le top des poêles + de détails', '1 Cuillère en bois Les meilleures ventes Acheter', '1 Blender chauffant Blender chauffant + de détails']
# 12:https://www.marmiton.org/recettes/recette_roti-de-boeuf-au-four-tout-simple_342546.aspx
# ['1 poivre', '1 sel', '1 thym', '400 g de rôti de boeuf bardé', "1 gousse d' ail", "2 cuillères à soupe d' huile d'olive", "12 cl d' eau"]
# ["Étape 1 Préchauffer le four à 220°C (thermostat 7-8). Mettre le rôti avec barde et ficelles dans un plat qui va au four. Couper la gousse d'ail en deux et en frotter le rôti. Parsemer le haut du rôti de thym et l'arroser d'huile d'olive. Poser les gousses d'ail sur le rôti.", "Étape 2 Enfourner pour 15 minutes de cuisson. Sortir le rôti et retirer la barde et la ficelle. Ajouter l'eau et faire tomber l'ail dans le plat", 'Étape 3 Saler et poivrer à convenance le rôti. Laisser cuire 10 à 15 minutes au four selon la cuisson désirée.']
# ['1 Four Top des meilleurs fours + de détails', '1 couteau Top 3 des couteaux + de détails', '1 couteau Top 3 des couteaux + de détails', '1 planche à découper Top des meilleures planches à découper + de détails', '1 Plat à gratin Notre top des plats à four + de détails', '1 dénoyauteur Les meilleures ventes Acheter', '1 plat + de détails']
# 13:https://www.marmiton.org/recettes/recette_fondue-savoyarde_21964.aspx
# ['400 g de comté', '400 g de beaufort', "200 g d' emmental", '1 cuillère à café de muscade', '1 cuillère à café de maïzena', '1 verre de Liqueur de kirsch', '1 pincée de poivre', '30 cl de vin blanc sec', "1 gousse d' ail", '1 oeuf (jaune)']
# ['Étape 1 Coupez les 3 fromages en petits dés.', "Étape 2 Frottez le caquelon avec la gousse d'ail et laissez-la dedans.", 'Étape 3 Versez 25 cl de vin blanc et faites chauffer.', 'Étape 4 Dans un petit récipient, versez le vin blanc restant (5 cl), la Maïzena et la noix de muscade. Remuez et réservez.', "Étape 5 Lorsque le vin 'frétille', versez le fromage (en plusieurs fois) sans cesser de remuer (avec une spatule en bois) sur feu doux/moyen.", 'Étape 6 Lorsque le fromage est bien fondu, versez le verre vin/Maïzena/muscade et continuez de remuer doucement.', "Étape 7 La préparation commence à être onctueuse et mousseuse, toujours un peu liquide. Poivrez et versez le kirsch. C'est prêt à servir!", "Étape 8 Le jaune d'oeuf est à mettre dans le caquelon lorsqu'il ne reste plus de liquide, afin d erécupérer le reste du fromage au fond."]
# ['1 Appareil à fondue Les meilleures ventes Acheter', '1 Cuillère en bois Les meilleures ventes Acheter', '1 couteau Top 3 des couteaux + de détails', '1 planche à découper Top des meilleures planches à découper + de détails', '1 saladier Les meilleures ventes Acheter']
# 14:https://www.marmiton.org/recettes/recette_filet-mignon-de-porc-a-la-moutarde_36310.aspx
# ['40 cl de crème fraîche', 'moutarde', 'beurre', '1 filet mignon de porc de 600 à 700 g environ', '25 cl de vin blanc sec', '1 bouillon de légumes', '500 g de champignon en boîte', "huile d'olive"]
# ['Étape 1 Couper la viande en morceaux et mettre le mélange huile + beurre à chauffer.', 'Étape 2 La faire dorer dans un mélange huile + beurre dans une cocotte.', 'Étape 3 Retirer les morceaux de la cocotte et jeter le surplus de gras.', 'Étape 4 Déglacer la cocotte avec le vin blanc, le bouillon cube, le jus des champignons et la crème (2/3 du pot).', "Étape 5 Tartiner le filet mignon de moutarde à l'ancienne et le remettre dans la cocotte avec les champignons.", 'Étape 6 Cuire environ 30 min, à feu très doux.', 'Étape 7 En fin de cuisson, ajouter le reste de crème, saler et poivrer.', 'Étape 8 Bon appétit.']
# ['1 cocotte + de détails', '1 Couteau Top des meilleurs couteaux de cuisine + de détails', '1 planche à découper Top des meilleures planches à découper + de détails', '1 balance de cuisine Top des meilleures balances + de détails']
# 15:https://www.marmiton.org/recettes/recette_carbonara-traditionnelle_340808.aspx
# ['6 pincées de poivre', '3 pincées de sel', "6 jaunes d'oeuf", '500 g de pancetta', '50 g de Parmesan Reggiano', "1 cuillère à soupe d' huile d'olive", '300 g de pâtes']
# ["Étape 1 Battre les jaunes d'œufs en y ajoutant 1 pincée de sel, 2 pincées de poivre et 40 g de parmigiano reggiano râpé.", "Étape 2 Remplir une grande casserole d'eau et la faire chauffer avec deux pincées de gros sel.", "Étape 3 Pendant ce temps, couper la pancetta en lamelles grossières et les faire dorer dans une poêle avec 1 cuillère à soupe d'huile d'olive.", 'Étape 4 Quand l’eau dans la casserole commence à bouillir mettez vos pâtes.', "Étape 5 Prendre deux cuillères à soupe d'eau de cuisson des pâtes, les verser dans le jaunes d'œufs puis remuer.", 'Étape 6 Réservez la pancetta et laissez la poêle au chaud.', 'Étape 7 Une fois la cuisson des pâtes al dente, les égoutter sommairement et les mettre dans la poêle et remuer.', "Étape 8 Verser le mélange dans un saladier et incorporez la préparation des jaunes d'œufs.", 'Étape 9 Ajouter la pancetta et deux pincées de poivre. Servez.']
# ['1 Râpe Top des meilleures râpes + de détails', '1 Fouet cuisine Top 5 des meilleurs fouets Acheter', '1 casserole Top 3 des batteries de casseroles + de détails', '1 Set 3 poêles Notre sélection des meilleures poêles + de détails', '1 pinceau 6,72€ + de détails', '1 Couteau Top des meilleurs couteaux de cuisine + de détails', '1 Cuillère en bois Les meilleures ventes Acheter', '1 saladier Les meilleures ventes Acheter', '1 dénoyauteur Les meilleures ventes Acheter']
# 16:https://www.marmiton.org/recettes/recette_rougail-saucisse_22851.aspx
# ['4 tomates (en conserve hors saison)', '4 oignons', 'thym', 'poivre', 'sel', '1 cuillère à café de curcuma (safran)', '1 piment oiseau (facultatif)', '6 saucisses fumées (genre diots de Savoie) ou 4 grosses saucisses fumées type Montbéliard', "6 gousses d' ail", 'laurier', "huile d'olive"]
# ["Étape 1 Piquez les saucisses et mettez les dans l'eau bouillante pendant 10 mn, dans la même marmite qui vous servira à la préparation du plat afin de garder les saveurs.", "Étape 2 Videz la marmite. Réservez les saucisses. Faites-y chauffer de l'huile d'olive.", "Étape 3 Faites revenir les oignons émincés et l'ail écrasé sans qu'ils soient trop colorés.", 'Étape 4 Coupez les saucisses en troncons de 1,5 cm puis faites les revenir avec les oignons. Au bout de 5 mn, ajoutez les tomates coupées en petits morceaux et les aromates (le piment en morceaux).', "Étape 5 Mélangez le tout puis laisser mijoter sur feu doux en ôtant le couvercle de temps à autre pour éliminer l'excès d'eau.", 'Étape 6 Servez avec du riz thai']
# ['1 Presse-ail Top des meilleurs presse-ails + de détails', '1 Couvercle Les meilleures ventes Acheter', '1 cocotte + de détails', '1 couteau Top 3 des couteaux + de détails', '1 planche à découper Top des meilleures planches à découper + de détails', '1 dénoyauteur Les meilleures ventes Acheter', '1 plat + de détails']
# 17:https://www.marmiton.org/recettes/recette_roti-de-porc-tout-simple_170153.aspx
# ['25 g de beurre', 'poivre', 'sel', '1 rôti de porc lardé de 600 g', "1 filet d' huile d'olive", "1 gousse d' ail coupée en lamelles", "5 cl d' eau"]
# ['Étape 1 Préchauffer le four à 210°C (thermostat 7) pendant 10 min.', "Étape 2 Pendant ce temps, mettre le rôti lardé par votre boucher dans un plat à four à bord haut. Verser l'huile, mettre le beurre en noisette sur la viande et mettre l'eau et l'ail sur le côté de la viande. Saler et poivrer.", "Étape 3 Mettre au four pendant 45 min environ. Au bout de 25 à 30 min, et régulièrement, sortir le rôti du four pour le mouiller avec le jus de cuisson et ajouter un peu d'eau le cas échéant. Au bout de 45 min votre rôti doit être bien cuit à cœur, doré sur le dessus et très tendre."]
# ['1 Four top des meilleurs fours + de détails', '1 Plat à gratin Notre top des plats à four + de détails', '1 balance de cuisine Top des meilleures balances + de détails', '1 plat + de détails']
# 18:https://www.marmiton.org/recettes/recette_boeuf-bourguignon-rapide_19218.aspx
# ['100 g de lardons', "50 g de beurre ou 3 cuillères à soupe d'huile", '⅔ l de vin rouge', '2 oignons', '2 cuillères à soupe de farine', 'sel', 'poivre', '800 g de boeuf pour bourguignon', "1 gousse d' ail", '1 bouquet garni', '250 g de champignons de Paris (en boîte)']
# ["Étape 1 Hacher les oignons. Peler l'ail.", 'Étape 2 Dans une cocotte minute, faire roussir la viande et les lardons dans l’huile ou le beurre.', 'Étape 3 Ajouter les oignons, les champignons égouttés et saupoudrer de fariner. Mélanger et laisser dorer un instant.', 'Étape 4 Mouiller avec le vin rouge qui doit recouvrir la viande.', 'Étape 5 Saler et poivrer.', 'Étape 6 Ajouter l’ail et le bouquet garni.', 'Étape 7 Fermer la cocotte minute.', 'Étape 8 Laisser cuire doucement 60 min à partir de la mise en rotation de la soupape.']
# ['1 Mixeur Les meilleures ventes Acheter', '1 cocotte + de détails', '1 pinceau 6,72€ + de détails', '1 Cuillère en bois Les meilleures ventes Acheter', '1 Mijoteuse électrique Les meilleures ventes Acheter', '1 couteau Top 3 des couteaux + de détails', '1 balance de cuisine Top des meilleures balances + de détails']
# 19:https://www.marmiton.org/recettes/recette_cuisses-de-poulet-au-four_67408.aspx
# ['1 oignon', '1 cuillère à café de thym (ou une branche)', '2 feuilles de laurier', '1 clou de girofle', '4 cuisses de poulet', "50 cl d' eau", "1 gousse d' ail", '1 bouillon de volaille', '3 genièvre', "1 cuillère à soupe d' huile d'olive"]
# ['Étape 1 Faire préchauffer le four à 210°C (thermostat 7). Déposer les cuisses de poulet dans un plat allant au four.', "Étape 2 Eplucher l'oignon, le couper en quatre. Le mettre dans le plat avec les cuisses. Ajouter, la gousse d'ail, le thym, les feuilles de laurier, le bouillon de cube coupé en quatre, les baies de genièvre, et le clou de girofle.", "Étape 3 Ajouter l'eau. Arroser les cuisses d'huile d'olive.", 'Étape 4 Enfourner à 210°C pendant 35 minutes. Arroser les cuisses de temps en temps pendant la cuisson.']
# ['1 Four Top des meilleurs fours + de détails', '1 Couteau Top des meilleurs couteaux de cuisine + de détails', '1 économe Top 5 des meilleurs économe + de détails', '1 dénoyauteur Les meilleures ventes Acheter', '1 plat + de détails']
# 20:https://www.marmiton.org/recettes/recette_chili-con-carne-facile_15415.aspx
# ['50 g de beurre', '2 oignons', '1 cuillère à café de chili en poudre', '2 cuillères à café de cumin en poudre', '1 grosse boîte de haricots rouges égouttés', '30 cl de bouillon de boeuf', 'sel', 'poivre', 'persil pour décorer', "2 gousses d' ail écrasées", '500 g de boeuf haché', '65 g de concentré de tomates']
# ['Étape 1 Préchauffer le four à 180°C (thermostat 6).', "Étape 2 Hacher l'oignon et l'ail.", "Étape 3 Dans une cocotte en fonte, faire fondre le beurre, et ensuite dorer doucement l'oignon et l’ail.", 'Étape 4 Incorporer le boeuf haché et laisser cuire doucement 10 min.', 'Étape 5 Mélanger le chili, le cumin, le concentré de tomates, et incorporer le tout au boeuf. Ajouter les haricots, le bouillon, du sel et du poivre.', 'Étape 6 Couvrir et cuire 25 min au four.']
# ['1 Four Top des meilleurs fours + de détails', '1 cocotte + de détails', '1 Cuillère en bois Les meilleures ventes Acheter', '1 Couvercle Les meilleures ventes Acheter', '1 Couteau Top des meilleurs couteaux de cuisine + de détails', '1 planche à découper Top des meilleures planches à découper + de détails', '1 balance de cuisine Top des meilleures balances + de détails']
# 21:https://www.marmiton.org/recettes/recette_paves-de-saumon-au-four-facile_80135.aspx
# ['5 oignons grelots avec le vert', 'poivre', 'sel', '2 pavés de saumon', '1 citron jaune', '1 verre de vin blanc', "huile d'olive", 'câpres (facultatif)']
# ['Étape 1 Mettre les pavés de saumon dans un plat allant au four.', 'Étape 2 Couper un citron en 2 et le presser sur les pavés. Couper le demi-citron restant en rondelles et les déposer directement sur le saumon.', 'Étape 3 Ciseler les petits oignons ainsi que le "vert" puis les mettre sur les pavés.', 'Étape 4 Ecraser les câpres et les poser sur le saumon (facultatif).', "Étape 5 Verser le vin blanc et un filet d'huile d'olive sur les saumons, saler (très peu), poivrer et faire cuire à 180°, thermostat 6, pendant environ 25 min."]
# ['1 Four Top des meilleurs fours + de détails', '1 Couteau Top des meilleurs couteaux de cuisine + de détails', '1 presse agrume + de détails', '1 Ciseaux de cuisine Top des meilleurs ciseaux de cuisine + de détails', '1 dénoyauteur Les meilleures ventes Acheter', '1 plat + de détails']
# 22:https://www.marmiton.org/recettes/recette_hachis-parmentier_17639.aspx
# ['300 g de purée', '2 oignons', '2 tomates fraîches ou pelées', '1 cuillère à soupe de farine', '30 g de beurre', '50 g de fromage râpé', 'sel', 'poivre', '400 g de viande hachée', "2 gousses d' ail", '1 pincée de herbes de Provence', "1 jaune d'oeuf", '30 g de Parmesan']
# ["Étape 1 Hacher l'oignon et l'ail. Les faire revenir dans le beurre jusqu'à ce qu'ils soient tendres.", 'Étape 2 Ajouter les tomates coupées en dés, la viande hachée, la farine, du sel, du poivre et les herbes de Provence.', "Étape 3 Quand tout est cuit, couper le feu et ajouter le jaune d'oeuf et un peu de parmesan. Bien mélanger.", "Étape 5 Préchauffer le four à 200°C (thermostat 6-7). Etaler au fond du plat à gratin. Préparer la purée. L'étaler au dessus de la viande. Saupoudrer de fromage râpé et faire gratiner."]
# ['1 Mixeur Les meilleures ventes Acheter', '1 Set 3 poêles Notre sélection des meilleures poêles + de détails', '1 Cuillère en bois Les meilleures ventes Acheter', '1 couteau Top 3 des couteaux + de détails', '1 Four top des meilleurs fours + de détails', '1 Plat à gratin Notre top des plats à four + de détails', '1 Râpe Top des meilleures râpes + de détails', '1 balance de cuisine Top des meilleures balances + de détails', '1 plat + de détails']
# 23:https://www.marmiton.org/recettes/recette_croziflette_165464.aspx
# ['200 g de lardons', '20 cl de crème fraîche', '1 oignon', '1 reblochon', 'poivre', 'sel', '300 g de crozet au sarrasin']
# ["Étape 1 Faire cuire les crozets dans l'eau bouillante salée pendant 20 minutes.", "Étape 2 Au bout de 10 minutes de cuisson des crozets, couper l'oignon et le faire revenir dans du beurre. Faites-la caraméliser.", 'Étape 3 Mettre les oignons de coté et faire revenir les lardons.', 'Étape 4 Mettre les oignons cuits lardons crème dans la poêle et faire réduire.', 'Étape 5 Égoutter les crozets.', 'Étape 6 Mettre dans le plat à gratin une couche de crozet, une couche de crème/lardons/oignons.', 'Étape 7 Remplir le plat de cette manière et mettre au-dessus le reblochon coupé en 2.', 'Étape 8 Faire cuire au four pendant 20 minutes à 200°C.']
# ['1 Set 3 poêles Notre sélection des meilleures poêles + de détails', '1 Couteau Top des meilleurs couteaux de cuisine + de détails', '1 Plat à gratin Notre top des plats à four + de détails', '1 Four top des meilleurs fours + de détails', '1 balance de cuisine Top des meilleures balances + de détails', '1 plat + de détails']
# 24:https://www.marmiton.org/recettes/recette_endives-au-jambon_25868.aspx
# ['12 tranches de jambon', '45 g de beurre', '45 g de farine', '60 g de gruyère râpé', 'poivre', 'sel', "2 kg d' endive", '75 g de crème', '30 cl de lait']
# ["Étape 1 Cuire les endives à l'eau bouillante pendant 45 min puis bien les égoutter.", 'Étape 2 Disposer les endives cuites sur les tranches de jambon puis rouler le tout.', 'Étape 3 Mettre les endives entourées de jambon dans un plat allant au four.', 'Étape 4 Faire une sauce Mornay en mélangeant le beurre, la farine, le lait et le fromage. Saler et poivrer.', 'Étape 5 Napper de sauce les endives au jambon et recouvrir de fromage râpé.', 'Étape 6 Gratiner pendant 10 à 15 min au four à 200°C (thermostat 6-7).']
# ['1 Four Top des meilleurs fours + de détails', '1 saladier Les meilleures ventes Acheter', '1 Râpe Top des meilleures râpes + de détails', '1 Blender chauffant Blender chauffant + de détails', '1 Plat à gratin Notre top des plats à four + de détails', '1 balance de cuisine Top des meilleures balances + de détails', '1 plat + de détails']
# 25:https://www.marmiton.org/recettes/recette_risotto-aux-champignons_312215.aspx
# ---------------------------------------------------------------------------
# NetworkError                              Traceback (most recent call last)
# Cell In[3], line 27
#      25 difficulty = await page.querySelectorEval('div.recipe-primary__item:nth-child(3) > span:nth-child(2)', 'node => node.textContent.trim()')
#      26 cout = await page.querySelectorEval('div.recipe-primary__item:nth-child(5) > span:nth-child(2)', 'node => node.textContent.trim()')
# ---> 27 nb_personne = await page.querySelectorEval('.recipe-ingredients__qt-counter__value', 'node => node.getAttribute("value")')
#      29 # Récupérer les ingrédients
#      30 liste_ingredients_temp = []
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyppeteer\page.py:393, in Page.querySelectorEval(self, selector, pageFunction, *args)
#     391 if not frame:
#     392     raise PageError('no main frame.')
# --> 393 return await frame.querySelectorEval(selector, pageFunction, *args)
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyppeteer\frame_manager.py:350, in Frame.querySelectorEval(self, selector, pageFunction, *args)
#     345 """Execute function on element which matches selector.
#     346
#     347 Details see :meth:`pyppeteer.page.Page.querySelectorEval`.
#     348 """
#     349 document = await self._document()
# --> 350 return await document.querySelectorEval(selector, pageFunction, *args)
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyppeteer\element_handle.py:413, in ElementHandle.querySelectorEval(self, selector, pageFunction, *args)
#     409 if not elementHandle:
#     410     raise ElementHandleError(
#     411         f'Error: failed to find element matching selector "{selector}"'
#     412     )
# --> 413 result = await self.executionContext.evaluate(
#     414     pageFunction, elementHandle, *args)
#     415 await elementHandle.dispose()
#     416 return result
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyppeteer\execution_context.py:53, in ExecutionContext.evaluate(self, pageFunction, force_expr, *args)
#      47 async def evaluate(self, pageFunction: str, *args: Any,
#      48                    force_expr: bool = False) -> Any:
#      49     """Execute ``pageFunction`` on this context.
#      50
#      51     Details see :meth:`pyppeteer.page.Page.evaluate`.
#      52     """
# ---> 53     handle = await self.evaluateHandle(
#      54         pageFunction, *args, force_expr=force_expr)
#      55     try:
#      56         result = await handle.jsonValue()
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyppeteer\execution_context.py:108, in ExecutionContext.evaluateHandle(self, pageFunction, force_expr, *args)
#      99     _obj = await self._client.send('Runtime.callFunctionOn', {
#     100         'functionDeclaration': f'{pageFunction}\n{suffix}\n',
#     101         'executionContextId': self._contextId,
#    (...)
#     105         'userGesture': True,
#     106     })
#     107 except Exception as e:
# --> 108     _rewriteError(e)
#     110 exceptionDetails = _obj.get('exceptionDetails')
#     111 if exceptionDetails:
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyppeteer\execution_context.py:238, in _rewriteError(error)
#     236     msg = 'Execution context was destroyed, most likely because of a navigation.'  # noqa: E501
#     237     raise type(error)(msg)
# --> 238 raise error
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyppeteer\execution_context.py:99, in ExecutionContext.evaluateHandle(self, pageFunction, force_expr, *args)
#      96     return self._objectHandleFactory(remoteObject)
#      98 try:
# ---> 99     _obj = await self._client.send('Runtime.callFunctionOn', {
#     100         'functionDeclaration': f'{pageFunction}\n{suffix}\n',
#     101         'executionContextId': self._contextId,
#     102         'arguments': [self._convertArgument(arg) for arg in args],
#     103         'returnByValue': False,
#     104         'awaitPromise': True,
#     105         'userGesture': True,
#     106     })
#     107 except Exception as e:
#     108     _rewriteError(e)
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:339, in Task.__wakeup(self, future)
#     337 def __wakeup(self, future):
#     338     try:
# --> 339         future.result()
#     340     except BaseException as exc:
#     341         # This may also be a cancellation.
#     342         self.__step(exc)
#
# File c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# NetworkError: Protocol error Runtime.callFunctionOn: Target closed.

# %%
df.to_csv("recettes_marmiton.csv", sep=";", encoding='utf-8', index=False)

# %%
data = pd.read_csv("recettes_marmiton.csv", sep=";", encoding='utf-8')
data['Ingrédients'][0]
# Out:
# '[\'2                                                                                                                                                       courgettes                                     , diamètre 4 ou 5 cm\', \'3                                                                                                                                                       carottes\', \'1                                         boîte moyenne                                                                          de                                     pois chiches\', \'beurre\', "1                                                                                                                                                       cuisse de dinde                                     d\'un peu plus d\'1 kg (et non un cochon d\'Inde)", \'6                                                                                                                                                       échalotes                                     (ou 2 gros oignons)\', \'1                                         bulbe                                                                          de                                     fenouil\', \'12                                                                                                                                                       dattes\', \'200                                         g                                                                          de                                     semoule moyenne\', "huile d\'olive", \'sel\', \'3                                         cuillères à soupe                                                                          de                                     persil                                     ciselé lyophilisé ou frais\', \'tabasco\', \'2                                         cuillères à soupe                                                                          de                                     piment                                     doux ou paprika en poudre\', \'2                                         cuillères à soupe                                                                          de                                     quatre-épices                                     (cannelle, muscade, girofle, poivre)\', \'2                                                                                                                                                       cubes de bouillon                                     de volaille\', "1                                         cuillère à café                                                                          d\'                                    ail                                     en semoule ou 2 gousses d’ail hachées", \'2                                         cuillères à café                                                                          de                                     laurier                                     en poudre (ou 2 feuilles)\']'
